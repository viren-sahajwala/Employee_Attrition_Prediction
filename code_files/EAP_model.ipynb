# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import datasets
from sklearn.metrics import accuracy_score,f1_score,recall_score, classification_report

from sklearn.metrics import roc_auc_score
import pickle
pd.set_option('display.max_columns', None)

# %%
hr_data = pd.read_csv("hr_data.csv")

# %%
hr_data
# Out:
#       Age  Attrition  BusinessTravel  DistanceFromHome  Education  \
# 0      51          0               1                 6          2
# 1      31          1               2                10          1
# 2      32          0               2                17          4
# 3      38          0               0                 2          5
# 4      32          0               1                10          1
# ...   ...        ...             ...               ...        ...
# 4405   42          0               1                 5          4
# 4406   29          0               1                 2          4
# 4407   25          0               1                25          2
# 4408   42          0               1                18          2
# 4409   40          0               1                28          3
#
#       EmployeeCount  EmployeeID  JobLevel  MonthlyIncome  NumCompaniesWorked  \
# 0                 1           1         1       5.117801                 1.0
# ...

# %% [markdown]
# # RandomForest

# %%
X=hr_data.drop(['Attrition','Over18','EmployeeID'],axis=1)
y=hr_data['Attrition']
X_train, X_test,y_train, y_test =train_test_split(X,y,train_size=0.7)

# %%
rfc=RandomForestClassifier()
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(X_test)

# %%
print("ACC:",accuracy_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("F1:",f1_score(y_test,y_pred))
# Out:
# ACC: 0.9977324263038548
# recall: 0.9844559585492227
# F1: 0.9921671018276762

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1130
#            1       1.00      0.98      0.99       193
#
#     accuracy                           1.00      1323
#    macro avg       1.00      0.99      1.00      1323
# weighted avg       1.00      1.00      1.00      1323

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %% [markdown]
# ## Predicting Probability score

# %%
df = pd.DataFrame(rfc.predict_proba(X_test)).drop(columns=0)

# %% [markdown]
# - Dropping the first column named 0 because 0 means No Attrition, 1 means yes Attrition
# - Since we are checking the likelihood of getting churned, we are using column named 1

# %%
df
# Out:
#          1
# 0     0.01
# 1     0.00
# 2     0.29
# 3     0.93
# 4     0.02
# ...    ...
# 1318  0.63
# 1319  0.64
# 1320  0.12
# 1321  0.14
# 1322  0.62
#
# [1323 rows x 1 columns]

# %%
X_test
# Out:
#       Age  BusinessTravel  DistanceFromHome  Education  EmployeeCount  \
# 984    40               1                 6          3              1
# 1065   28               0                 7          3              1
# 2699   22               0                 8          3              1
# 4323   19               2                10          2              1
# 1271   37               1                 4          3              1
# ...   ...             ...               ...        ...            ...
# 2510   46               1                10          3              1
# 1137   31               2                 2          1              1
# 3224   38               1                 1          3              1
# 3956   31               1                 8          5              1
# 978    36               1                 1          3              1
#
#       JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# ...

# %%
df.reset_index(drop=True, inplace = True)

# %%
rfc.predict_proba(X_train)
# Out:
# array([[0.98, 0.02],
#        [0.96, 0.04],
#        [1.  , 0.  ],
#        ...,
#        [1.  , 0.  ],
#        [0.97, 0.03],
#        [1.  , 0.  ]])

# %%
# Saving model using pickle
pickle.dump(rfc, open('model.pkl','wb'))

# %%
# Loading model to compare the results
model = pickle.load( open('model.pkl','rb'))

# %%
id = 102
hr_data.loc[hr_data['EmployeeID'] == id]
# Out:
#      Age  Attrition  BusinessTravel  DistanceFromHome  Education  \
# 101   36          0               2                 6          3
#
#      EmployeeCount  EmployeeID  JobLevel  MonthlyIncome  NumCompaniesWorked  \
# 101              1         102         2       4.678609                 4.0
#
#     Over18  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 101      Y                 13              8                 1
#
#      TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 101               16.0                      2              13
#
#      YearsSinceLastPromotion  YearsWithCurrManager  \
# 101                        1                    12
#
#      Department_Human Resources  Department_Research & Development  \
# 101                           0                                  1
#
#      Department_Sales  EducationField_Human Resources  \
# 101                 0                               0
#
# ...

# %%
id = 1048
for i in hr_data["EmployeeID"]:
    if i == id:
        input_variable = hr_data.loc[hr_data["EmployeeID"] == i].drop(['Attrition','Over18','EmployeeID'],axis=1)
score = model.predict_proba(input_variable)[0][1]
print(score)
# Out:
# 0.02

# %%
score.dtype
# Out:
# dtype('float64')

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

def calc_score(emp_id):
    hr_data = pd.read_csv("hr_data.csv")
    X=hr_data.drop(['Attrition','Over18','EmployeeID'],axis=1).values
    y=hr_data['Attrition'].values
    X_train, X_test,y_train, y_test =train_test_split(X,y,train_size=0.8)
    model=RandomForestClassifier()
    model.fit(X_train,y_train)
    
    for i in hr_data["EmployeeID"]:
        if i == emp_id:
            input_variable = hr_data.loc[hr_data["EmployeeID"] == i].drop(['Attrition','Over18','EmployeeID'],axis=1)
            score = df.model.predict_proba(input_variable)[0][1]
    return score
calc_score(786)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# 0.0

# %%
score="21"
type(score)
# Out:
# str

# %%
score = int(score)

# %%
type(score)
# Out:
# int
